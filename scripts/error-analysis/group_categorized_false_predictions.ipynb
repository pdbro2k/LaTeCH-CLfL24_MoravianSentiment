# %%
import pandas as pd

# %% [markdown]
# # Load Data

# %%
data_path = "../../data/error-analysis/"

# %%
false_prediction_df = pd.read_csv(data_path + "moravian_deu_test_gbert_fine-tuned_false-predictions_categorized.csv", index_col=0)
false_prediction_df
# Out:
#                                                   text    y_true y_predicted  \
# 6    Sie stellte sich ihren Heimgang oft nahe vor, ...   neutral    positive
# 21   bau dir ein Haus und heirate die Person, die d...  positive     neutral
# 26   Einst redete er mich folgendermaßen an: “Mein ...  positive     neutral
# 27   die strenge Kälte war uns bei unsrer dünnen Kl...  negative    positive
# 28   ich lies mich beym Pfarrer {NAME} melden, daß ...  positive     neutral
# ..                                                 ...       ...         ...
# 420  ich glaubte auch es würde nichts aus mir bis i...  negative     neutral
# 427  daß geschahe sehr Solen, ingegenwart vieler In...   neutral    positive
# 428  als wir aber etwa noch 4 Meilen davon entfernt...   neutral    negative
# 430  Der Capitain sagte darauf, daß er gekommen sei...  positive     neutral
# 433  hätte Er nicht Seine Hand über mich gehalten, ...  positive    negative
#
#                category
# 6               unclear
# 21              unclear
# 26              unclear
# 27   multiple negations
# 28              unclear
# ..                  ...
# 420             unclear
# 427      short sentence
# 428             unclear
# 430     mixed sentiment
# 433  multiple negations
#
# [84 rows x 4 columns]

# %% [markdown]
# # Add Confusion Type Column

# %%
false_prediction_df["confusion"] = false_prediction_df[["y_true", "y_predicted"]].apply(lambda x: "<>".join(sorted(x)), axis=1)
false_prediction_df
# Out:
#                                                   text    y_true y_predicted  \
# 6    Sie stellte sich ihren Heimgang oft nahe vor, ...   neutral    positive
# 21   bau dir ein Haus und heirate die Person, die d...  positive     neutral
# 26   Einst redete er mich folgendermaßen an: “Mein ...  positive     neutral
# 27   die strenge Kälte war uns bei unsrer dünnen Kl...  negative    positive
# 28   ich lies mich beym Pfarrer {NAME} melden, daß ...  positive     neutral
# ..                                                 ...       ...         ...
# 420  ich glaubte auch es würde nichts aus mir bis i...  negative     neutral
# 427  daß geschahe sehr Solen, ingegenwart vieler In...   neutral    positive
# 428  als wir aber etwa noch 4 Meilen davon entfernt...   neutral    negative
# 430  Der Capitain sagte darauf, daß er gekommen sei...  positive     neutral
# 433  hätte Er nicht Seine Hand über mich gehalten, ...  positive    negative
#
#                category           confusion
# 6               unclear   neutral<>positive
# 21              unclear   neutral<>positive
# 26              unclear   neutral<>positive
# 27   multiple negations  negative<>positive
# 28              unclear   neutral<>positive
# ..                  ...                 ...
# 420             unclear   negative<>neutral
# 427      short sentence   neutral<>positive
# 428             unclear   negative<>neutral
# 430     mixed sentiment   neutral<>positive
# 433  multiple negations  negative<>positive
#
# [84 rows x 5 columns]

# %% [markdown]
# # Group by Category (and Confusion Type)

# %%
false_prediction_df.groupby("category").count()[["text"]]
# Out:
#                     text
# category
# long sentence         25
# mixed sentiment        8
# multiple negations     4
# short sentence         7
# unclear               40

# %%
grouped_df = false_prediction_df.groupby(["category", "confusion"]).count()["text"].unstack("confusion").fillna(0)
grouped_df
# Out:
# confusion           negative<>neutral  negative<>positive  neutral<>positive
# category
# long sentence                     6.0                17.0                2.0
# mixed sentiment                   0.0                 7.0                1.0
# multiple negations                0.0                 4.0                0.0
# short sentence                    0.0                 1.0                6.0
# unclear                          12.0                 8.0               20.0

# %%
# make relative
grouped_df = grouped_df / len(false_prediction_df)

# add totals
grouped_df["Total"] = grouped_df.sum(axis=1)
grouped_df.loc['Total',:] = grouped_df.sum(axis=0)
grouped_df.round(2)
# Out:
# confusion           negative<>neutral  negative<>positive  neutral<>positive  \
# category
# long sentence                    0.07                0.20               0.02
# mixed sentiment                  0.00                0.08               0.01
# multiple negations               0.00                0.05               0.00
# short sentence                   0.00                0.01               0.07
# unclear                          0.14                0.10               0.24
# Total                            0.21                0.44               0.35
#
# confusion           Total
# category
# long sentence        0.30
# mixed sentiment      0.10
# multiple negations   0.05
# short sentence       0.08
# unclear              0.48
# Total                1.00
